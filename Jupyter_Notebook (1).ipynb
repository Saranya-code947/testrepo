# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# Jupyter_Notebook(1).ipynb

# %% [markdown]
# datascience basics

# %% [markdown]
# this is a project on data science where we are asked to create some markdown cells and some code cells for the purpose of evaluation

# %% [markdown]
# The datascience languages are
#
# Python
# R
# Scala
# Perl
# Matlab
# C++

# %% [markdown]
# The datasciece libraries are
#
# Tensorflow
# Numpy
# scipy
# pandas
# Scikit-Learn
# Pytorch
# Matplotlib

# %% [markdown]
# The datascience tools are
#
# SAS
# Apache Spark
# Big ML

# %% [markdown]
# arithmetic expression examples.
#
# Arithmetic operations
# code = compile("5 + 4", "", "eval") eval(code)
#
# Result: 9
#
# Arithmetic operations
# code1 = compile("(5 + 7) * 2", "", "eval") eval(code1)
#
# Result: 24

# %%
(3*4)+5
